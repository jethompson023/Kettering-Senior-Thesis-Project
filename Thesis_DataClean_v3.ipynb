# %% [markdown]
# <a href="https://colab.research.google.com/github/jethompson023/Kettering-Senior-Thesis-Project/blob/main/Thesis_DataClean_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Note: For version two look to implement both/or one Polars API or the Numba API

# %%
#Imports for our Script
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import pandas as pd
import numpy as np
import os
import json
from datetime import *

# %% [markdown]
# ##Importing of the Data

# %%
#Add google authentication ok
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

#Import the data from the Google Sheet
workbook = gc.open_by_key('1mjE530k7fYKkPh9VPcqfElrrzMkw59uUTPQ34VWH0wA')
worksheet = workbook.worksheet('POU')

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()

# Convert to a DataFrame and render.
pou_data = pd.DataFrame.from_records(rows)

# %%
#Next we are going to format the rows to allow for the data to get into a data frame
new_header = pou_data.iloc[0] #grab the first row for the header
pou_data = pou_data[0:] #take the data less the header row
pou_data.columns = new_header #set the header row as the df header
pou_data  = pou_data.drop(labels=0, axis=0)
pou_data
# Out:
# 0            Item_no               Item Description Qty Status Serial Number  \
# 1       03-33412-875      ISOLATOR-FTK,BAND,M2,CBOC   2      T        UB2964
# 2      A14-16601-000    STUBSHAFT-STEERING,M2,EPA07   1      I        NV7601
# 3       03-40538-002                FWS-DETROIT,WIF   1      I        NV7659
# 4       04-16509-010             PIPE-5"X10"PLN,CRV   1      I        UD5183
# 5      A17-21151-028                   HOOD-106,BZL   1      Y        UK8929
# ...              ...                            ...  ..    ...           ...
# 33912  A12-28407-000                   FT VLV-M2,1V   1      T        NY8456
# 33913   22-65293-000       TRIM FASCIA-OVHD CONSOLE   1      T        UJ8400
# 33914   22-65293-000       TRIM FASCIA-OVHD CONSOLE   1      T        UK9324
# 33915  A22-74243-048  MIR-M2,BRT,HTD,RMT,CUM AAT,LH   1      I        NY8456
# 33916  A66-01266-060   WIRE-ASSY,3/8-1/4,BOOT,#2,60   1      E        UF3333
#
# 0     Reason Code                                     Shortage Notes  \
# 1             MHE  on kit cart                                   ...
# 2             PLT  INSTALLED BUT NEEDS VERIFIED AND SIGNED  OFF.....
# 3             VPD  TIED TO MOUNTING BRKT.. S WELCH               ...
# 4             MID  production wrote up part and did not nee d the...
# 5             VPD  VENDOR SHORT                                  ...
# ...           ...                                                ...
# 33912         MHE  on kit cart/ klw                              ...
# 33913         MHE  installed but needs verified and signed  off.....
# 33914         MHE  in cab per Justin                             ...
# 33915         MHE  ON KIT CART                                   ...
# 33916         ENG  SHOPCALL UF3333 NEED HOT PLEASE ADVISE   ESD  ...
#
# 0     Team Found Team Resp  Date Found Time Found (Pacific)  \
# 1            541       521  05/19/2022             05:02:55
# 2            207       207  07/25/2022             11:05:44
# 3            501       501  07/25/2022             08:23:47
# 4            249       926  07/28/2022             19:49:52
# 5                           07/29/2022             10:25:19
# ...          ...       ...         ...                  ...
# 33912        926       926  09/13/2022             02:16:40
# 33913        926       926  09/13/2022             06:06:43
# 33914        926       926  09/13/2022             06:06:42
# 33915        926       926  09/13/2022             02:12:48
# 33916                       09/13/2022             10:41:42
#
# 0     SHORT_FOUND_EMP_ID Date_chassis_start date_veh_offln date_mfg_rlse  \
# 1                ricrisp         2022-08-18     2022-08-18
# 2                staffod         2022-08-11     2022-08-12    2022-08-14
# 3                MILLETA         2022-08-11     2022-08-12    2022-08-19
# 4                MASBURY         2022-08-15     2022-08-16
# 5                                2022-08-18
# ...                  ...                ...            ...           ...
# 33912            MELIWIL         2022-09-13     2022-09-13
# 33913            jeffgra         2022-09-13     2022-09-13
# 33914            jeffgra         2022-09-13     2022-09-13
# 33915            MELIWIL         2022-09-13     2022-09-13
# 33916                            2022-09-08     2022-09-08
#
# 0     PRIM_SHOP_ADDR SCD_SHOP_ADDR_1 SCD_SHOP_ADDR_2 SCD_SHOP_ADDR_3  \
# 1              RPK 2          02817R
# 2              TUG03          61113R
# 3             60516E          02524R          02524R
# 4              6600C           02700
# 5              32500
# ...              ...             ...             ...             ...
# 33912         QKPULL          60004L                           MIN 1
# 33913          RPK 3          61205L
# 33914          RPK 3          61205L
# 33915         KTMIRR          MIRSEQ
# 33916         025KIT           02510
#
# 0     SCD_SHOP_ADDR_4
# 1              CRITIC
# 2              CRITIC
# 3
# 4
# 5
# ...               ...
# 33912           MAX 1
# 33913
# 33914
# 33915
# 33916
#
# [33916 rows x 20 columns]

# %%
#Drop the Duplicates
pou_data.drop_duplicates(subset="Time Found (Pacific)", keep='first')

#Check the row count again to see if the data was cleaned properly
print('Row Count is: ', len(pou_data.axes[0]))
# Out:
# Row Count is:  33916

# %% [markdown]
# #Timestamp Conversion

# %% [markdown]
# ##Convert the current Datatype from Object to datatime[ns]

# %%
pou_data['Time Found (Pacific)'] = pd.to_datetime(pou_data['Time Found (Pacific)'])
pou_data.dtypes
# Out:
# 0
# Item_no                         object
# Item Description                object
# Qty                             object
# Status                          object
# Serial Number                   object
# Reason Code                     object
# Shortage Notes                  object
# Team Found                      object
# Team Resp                       object
# Date Found                      object
# Time Found (Pacific)    datetime64[ns]
# SHORT_FOUND_EMP_ID              object
# Date_chassis_start              object
# date_veh_offln                  object
# date_mfg_rlse                   object
# PRIM_SHOP_ADDR                  object
# SCD_SHOP_ADDR_1                 object
# SCD_SHOP_ADDR_2                 object
# SCD_SHOP_ADDR_3                 object
# SCD_SHOP_ADDR_4                 object
# dtype: object

# %% [markdown]
# ##Create temp array for the column then create new column for the Eastern Standard Time Conversion

# %%
list_temp = []
for columns in pou_data['Time Found (Pacific)']:
  list_temp.append(pd.Timestamp(columns, tz = 'US/Pacific').tz_convert('US/Eastern'))
pou_data['time_found_EST'] = list_temp
print(pou_data['time_found_EST'])
# Out:
# 1       2022-10-27 08:02:55-04:00
# 2       2022-10-27 14:05:44-04:00
# 3       2022-10-27 11:23:47-04:00
# 4       2022-10-27 22:49:52-04:00
# 5       2022-10-27 13:25:19-04:00
#                    ...
# 33912   2022-10-27 05:16:40-04:00
# 33913   2022-10-27 09:06:43-04:00
# 33914   2022-10-27 09:06:42-04:00
# 33915   2022-10-27 05:12:48-04:00
# 33916   2022-10-27 13:41:42-04:00
# Name: time_found_EST, Length: 33916, dtype: datetime64[ns, US/Eastern]

# %% [markdown]
# ###Set DataTypes for DataFrame

# %%
#Check what datatypes are in the dataframe
pou_data.dtypes
# Out:
# 0
# Item_no                                     object
# Item Description                            object
# Qty                                         object
# Status                                      object
# Serial Number                               object
# Reason Code                                 object
# Shortage Notes                              object
# Team Found                                  object
# Team Resp                                   object
# Date Found                                  object
# Time Found (Pacific)                datetime64[ns]
# SHORT_FOUND_EMP_ID                          object
# Date_chassis_start                          object
# date_veh_offln                              object
# date_mfg_rlse                               object
# PRIM_SHOP_ADDR                              object
# SCD_SHOP_ADDR_1                             object
# SCD_SHOP_ADDR_2                             object
# SCD_SHOP_ADDR_3                             object
# SCD_SHOP_ADDR_4                             object
# time_found_EST          datetime64[ns, US/Eastern]
# dtype: object

# %% [markdown]
# ##Create new Dataframe for POU analysis

# %% [markdown]
# Data Callouts for the POU Data
#
# 1.   Item_no
# 2.   Item Description
# 3.   Serial Number
# 4.   Reason
# 5.   Reason Code
# 6.   Status
# 7.   Team Responsible
# 8.   Primary Shop Address
# 9.   C/S Quantity
# 10.  Qty
# 11.  Time Found in EST
# 12.  Date

# %%
#Create the new dataframe to send data into the Google Sheet
pou_data_cleaned = pd.DataFrame(columns=['Item_no', 'Item Description','Serial Number','Reason Code', 'Status','Operating Units', 'Team Responsible', 'Quantity', 'Date', 'Time Found (EST)'])
pou_data_cleaned['Item_no'] = pou_data['Item_no']
pou_data_cleaned['Item Description'] = pou_data['Item Description']
pou_data_cleaned['Reason Code'] = pou_data['Reason Code']
pou_data_cleaned['Serial Number'] = pou_data['Serial Number']
pou_data_cleaned['Status'] = pou_data['Status']
pou_data_cleaned['Team Responsible'] = pd.to_numeric(pou_data['Team Resp'])
pou_data_cleaned['Quantity'] = pou_data['Qty']
pou_data_cleaned['Date'] = pd.to_datetime(pou_data['Date Found'])
pou_data_cleaned['Time Found (EST)'] = pou_data['time_found_EST']
pou_data_cleaned
# Out:
#              Item_no               Item Description Serial Number Reason Code  \
# 1       03-33412-875      ISOLATOR-FTK,BAND,M2,CBOC        UB2964         MHE
# 2      A14-16601-000    STUBSHAFT-STEERING,M2,EPA07        NV7601         PLT
# 3       03-40538-002                FWS-DETROIT,WIF        NV7659         VPD
# 4       04-16509-010             PIPE-5"X10"PLN,CRV        UD5183         MID
# 5      A17-21151-028                   HOOD-106,BZL        UK8929         VPD
# ...              ...                            ...           ...         ...
# 33912  A12-28407-000                   FT VLV-M2,1V        NY8456         MHE
# 33913   22-65293-000       TRIM FASCIA-OVHD CONSOLE        UJ8400         MHE
# 33914   22-65293-000       TRIM FASCIA-OVHD CONSOLE        UK9324         MHE
# 33915  A22-74243-048  MIR-M2,BRT,HTD,RMT,CUM AAT,LH        NY8456         MHE
# 33916  A66-01266-060   WIRE-ASSY,3/8-1/4,BOOT,#2,60        UF3333         ENG
#
#       Status Operating Units  Team Responsible Quantity       Date  \
# 1          T             NaN             521.0        2 2022-05-19
# 2          I             NaN             207.0        1 2022-07-25
# 3          I             NaN             501.0        1 2022-07-25
# 4          I             NaN             926.0        1 2022-07-28
# 5          Y             NaN               NaN        1 2022-07-29
# ...      ...             ...               ...      ...        ...
# 33912      T             NaN             926.0        1 2022-09-13
# 33913      T             NaN             926.0        1 2022-09-13
# 33914      T             NaN             926.0        1 2022-09-13
# 33915      I             NaN             926.0        1 2022-09-13
# 33916      E             NaN               NaN        1 2022-09-13
#
#                Time Found (EST)
# 1     2022-10-27 08:02:55-04:00
# 2     2022-10-27 14:05:44-04:00
# 3     2022-10-27 11:23:47-04:00
# 4     2022-10-27 22:49:52-04:00
# 5     2022-10-27 13:25:19-04:00
# ...                         ...
# 33912 2022-10-27 05:16:40-04:00
# 33913 2022-10-27 09:06:43-04:00
# 33914 2022-10-27 09:06:42-04:00
# 33915 2022-10-27 05:12:48-04:00
# 33916 2022-10-27 13:41:42-04:00
#
# [33916 rows x 10 columns]

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# #Formatting Data

# %% [markdown]
# ##Classify the Operating Units

# %% [markdown]
# Breakdown of Operating Units - numbers differ from shift to shift
#
# 1.   CIW / Western Star: -  100 - 199
# 2.   Final Cab: 200 - 299
# 3.   Paint - 300 - 399
# 4.   Pool 1/Engine Line: 400 - 499
# 5.   Final Chassis: 500 - 599
# 6.   Offline - 800 - 899

# %%
#Create new column within the dataframe
pou_data_cleaned['Operating Units'] = 'Workstation'

# %%
def op_units(x):
  if x >= 100 and x < 199:
    return 'CIW/Western'
  elif x >= 200 and x < 299:
    return 'Final Cab'
  elif x >= 300 and x < 399:
    return 'Paint'
  elif x >= 400 and x < 499:
    return 'Pool 1/Engine Line'
  elif x >= 500 and x < 599:
    return 'Final Chassis'
  else:
    return 'Workstation'

# %%
pou_data_cleaned['Operating Units'] = pou_data_cleaned['Team Responsible'].apply(op_units)

# %%
pou_data_cleaned
# Out:
#              Item_no               Item Description Serial Number Reason Code  \
# 1       03-33412-875      ISOLATOR-FTK,BAND,M2,CBOC        UB2964         MHE
# 2      A14-16601-000    STUBSHAFT-STEERING,M2,EPA07        NV7601         PLT
# 3       03-40538-002                FWS-DETROIT,WIF        NV7659         VPD
# 4       04-16509-010             PIPE-5"X10"PLN,CRV        UD5183         MID
# 5      A17-21151-028                   HOOD-106,BZL        UK8929         VPD
# ...              ...                            ...           ...         ...
# 33912  A12-28407-000                   FT VLV-M2,1V        NY8456         MHE
# 33913   22-65293-000       TRIM FASCIA-OVHD CONSOLE        UJ8400         MHE
# 33914   22-65293-000       TRIM FASCIA-OVHD CONSOLE        UK9324         MHE
# 33915  A22-74243-048  MIR-M2,BRT,HTD,RMT,CUM AAT,LH        NY8456         MHE
# 33916  A66-01266-060   WIRE-ASSY,3/8-1/4,BOOT,#2,60        UF3333         ENG
#
#       Status Operating Units  Team Responsible Quantity       Date  \
# 1          T   Final Chassis             521.0        2 2022-05-19
# 2          I       Final Cab             207.0        1 2022-07-25
# 3          I   Final Chassis             501.0        1 2022-07-25
# 4          I     Workstation             926.0        1 2022-07-28
# 5          Y     Workstation               NaN        1 2022-07-29
# ...      ...             ...               ...      ...        ...
# 33912      T     Workstation             926.0        1 2022-09-13
# 33913      T     Workstation             926.0        1 2022-09-13
# 33914      T     Workstation             926.0        1 2022-09-13
# 33915      I     Workstation             926.0        1 2022-09-13
# 33916      E     Workstation               NaN        1 2022-09-13
#
#                Time Found (EST)
# 1     2022-10-27 08:02:55-04:00
# 2     2022-10-27 14:05:44-04:00
# 3     2022-10-27 11:23:47-04:00
# 4     2022-10-27 22:49:52-04:00
# 5     2022-10-27 13:25:19-04:00
# ...                         ...
# 33912 2022-10-27 05:16:40-04:00
# 33913 2022-10-27 09:06:43-04:00
# 33914 2022-10-27 09:06:42-04:00
# 33915 2022-10-27 05:12:48-04:00
# 33916 2022-10-27 13:41:42-04:00
#
# [33916 rows x 10 columns]

# %% [markdown]
# ### Format the Timestamp Column

# %%
time_found = pd.Series(pou_data_cleaned['Time Found (EST)'])
new_time_found = time_found.dt.time

# %%
pou_data_cleaned['Time Found'] = new_time_found
del pou_data_cleaned['Time Found (EST)']
pou_data_cleaned
# Out:
#              Item_no               Item Description Serial Number Reason Code  \
# 1       03-33412-875      ISOLATOR-FTK,BAND,M2,CBOC        UB2964         MHE
# 2      A14-16601-000    STUBSHAFT-STEERING,M2,EPA07        NV7601         PLT
# 3       03-40538-002                FWS-DETROIT,WIF        NV7659         VPD
# 4       04-16509-010             PIPE-5"X10"PLN,CRV        UD5183         MID
# 5      A17-21151-028                   HOOD-106,BZL        UK8929         VPD
# ...              ...                            ...           ...         ...
# 33912  A12-28407-000                   FT VLV-M2,1V        NY8456         MHE
# 33913   22-65293-000       TRIM FASCIA-OVHD CONSOLE        UJ8400         MHE
# 33914   22-65293-000       TRIM FASCIA-OVHD CONSOLE        UK9324         MHE
# 33915  A22-74243-048  MIR-M2,BRT,HTD,RMT,CUM AAT,LH        NY8456         MHE
# 33916  A66-01266-060   WIRE-ASSY,3/8-1/4,BOOT,#2,60        UF3333         ENG
#
#       Status Operating Units  Team Responsible Quantity       Date Time Found
# 1          T   Final Chassis             521.0        2 2022-05-19   08:02:55
# 2          I       Final Cab             207.0        1 2022-07-25   14:05:44
# 3          I   Final Chassis             501.0        1 2022-07-25   11:23:47
# 4          I     Workstation             926.0        1 2022-07-28   22:49:52
# 5          Y     Workstation               NaN        1 2022-07-29   13:25:19
# ...      ...             ...               ...      ...        ...        ...
# 33912      T     Workstation             926.0        1 2022-09-13   05:16:40
# 33913      T     Workstation             926.0        1 2022-09-13   09:06:43
# 33914      T     Workstation             926.0        1 2022-09-13   09:06:42
# 33915      I     Workstation             926.0        1 2022-09-13   05:12:48
# 33916      E     Workstation               NaN        1 2022-09-13   13:41:42
#
# [33916 rows x 10 columns]

# %% [markdown]
# #Send Data to Google Sheets

# %%
#Convert to type string 
pou_data_cleaned['Time Found'] = pou_data_cleaned['Time Found'].astype(str)
pou_data_cleaned['Date'] = pou_data_cleaned['Date'].astype(str)
pou_data_cleaned['Team Responsible'] = pou_data_cleaned['Team Responsible'].astype(str)

# %%
#Convert dataset into a list
clean_data = pou_data_cleaned.to_numpy().tolist()

#add the headers
headers = pou_data_cleaned.columns.tolist()

#combine with 'clean_data'
dataToWrite = [headers] + clean_data

#Get the Worksheet
wsCleanData = workbook.worksheet('POU_Cleaned_Data')

#Send/Write cleaned data to Google Sheet
wsCleanData.update(None, dataToWrite)
# Out:
# {'spreadsheetId': '1mjE530k7fYKkPh9VPcqfElrrzMkw59uUTPQ34VWH0wA',
#  'updatedRange': 'POU_Cleaned_Data!A1:J33917',
#  'updatedRows': 33917,
#  'updatedColumns': 10,
#  'updatedCells': 339170}
